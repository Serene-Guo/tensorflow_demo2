# %%
from mnist_class_plot import plot_example_errors
# %run mnist_recognizer.py
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Size of:
# - Training-set:		55000
# - Test-set:		10000
# - Validation-set:	5000
# Training epoch: 1
# iter 0:	 loss=2.28, 	Training Accuracy=53.0%
# iter 100:	 loss=0.37, 	Training Accuracy=90.0%
# iter 200:	 loss=0.33, 	Training Accuracy=90.0%
# iter 300:	 loss=0.27, 	Training Accuracy=89.0%
# iter 400:	 loss=0.16, 	Training Accuracy=94.0%
# iter 500:	 loss=0.20, 	Training Accuracy=96.0%
# ---------------------------------------------------------------
# Epoch: 0, validation loss: 0.21, validation accuracy: 94.2%
# ---------------------------------------------------------------
# Training epoch: 2
# iter 0:	 loss=0.29, 	Training Accuracy=89.0%
# iter 100:	 loss=0.17, 	Training Accuracy=93.0%
# iter 200:	 loss=0.16, 	Training Accuracy=95.0%
# ...
